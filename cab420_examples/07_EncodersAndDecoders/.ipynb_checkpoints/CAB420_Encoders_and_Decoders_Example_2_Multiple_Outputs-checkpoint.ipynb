# %% [markdown]
# # CAB420, Encoders and Decoders, Example 2: Multiple Outputs
# Dr Simon Denman (s.denman@qut.edu.au)
#
# ## Overview
# In this example we will look at getting a network to do two things at once. Multi-task learning is generally very common with deep learning architectures. Largely because:
# * It's easy
# * It's often very useful
#
# By having multiple outputs we often find that one task can regularise the other, i.e. the model is less likely to overfit and will generalise better. Both tasks don't always need to be super meaninful either, we can for example have one task that is simply an auto-encoder. This on it's own may not be of use to us, but it can help the other task that we're trying to learn depending on the circumstances.
#
# ## Too Long; Didn't Read:
# * Multi-task learning is exactly what it sounds like - getting a network to do two things at once
# * To do this, we need to setup multiple outputs, and multiple losses. The total loss is just the sum of these
# * Generally, if the tasks are related we'll get better performance leanring both than learning either one individually, as one task helps regularise the other
# * We can weight the tasks, such that one task is given more importance than the other

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import datetime
import numpy


import keras
from keras import layers

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

import pydot
import IPython
from IPython.display import SVG
from keras.utils import model_to_dot, plot_model

import cv2
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768893100.881055 2916845 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768893100.884949 2916845 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768893100.895333 2916845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768893100.895348 2916845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768893100.895351 2916845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768893100.895353 2916845 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ## The Data
#
# We're going to use the same data we used in the one of our early deep convolutional neural network examples. This was a rotated version of MNIST. This time, we'll try to classify both the rotation and the class of digit.
#
# Data preparation will follow exactly the same process as the earlier example.

# %%
def rotate(image, angle):
    """
    Rotates an OpenCV 2 / NumPy image about it's centre by the given angle
    (in degrees). The returned image will be large enough to hold the entire
    new image, with a black background
    Source: http://stackoverflow.com/questions/16702966/rotate-image-and-crop-out-black-borders
    """
    # Get the image size
    image_size = (image.shape[1], image.shape[0])
    image_center = tuple(numpy.array(image_size) / 2)

    # Convert the OpenCV 3x2 rotation matrix to 3x3
    rot_mat = numpy.vstack(
        [cv2.getRotationMatrix2D(image_center, angle, 1.0), [0, 0, 1]]
    )

    rot_mat_notranslate = numpy.matrix(rot_mat[0:2, 0:2])

    # Shorthand for below calcs
    image_w2 = image_size[0] * 0.5
    image_h2 = image_size[1] * 0.5

    # Obtain the rotated coordinates of the image corners
    rotated_coords = [
        (numpy.array([-image_w2,  image_h2]) * rot_mat_notranslate).A[0],
        (numpy.array([ image_w2,  image_h2]) * rot_mat_notranslate).A[0],
        (numpy.array([-image_w2, -image_h2]) * rot_mat_notranslate).A[0],
        (numpy.array([ image_w2, -image_h2]) * rot_mat_notranslate).A[0]
    ]

    # Find the size of the new image
    x_coords = [pt[0] for pt in rotated_coords]
    x_pos = [x for x in x_coords if x > 0]
    x_neg = [x for x in x_coords if x < 0]

    y_coords = [pt[1] for pt in rotated_coords]
    y_pos = [y for y in y_coords if y > 0]
    y_neg = [y for y in y_coords if y < 0]

    right_bound = max(x_pos)
    left_bound = min(x_neg)
    top_bound = max(y_pos)
    bot_bound = min(y_neg)

    new_w = int(abs(right_bound - left_bound))
    new_h = int(abs(top_bound - bot_bound))

    # We require a translation matrix to keep the image centred
    trans_mat = numpy.matrix([
        [1, 0, int(new_w * 0.5 - image_w2)],
        [0, 1, int(new_h * 0.5 - image_h2)],
        [0, 0, 1]
    ])

    # Compute the tranform for the combined rotation and translation
    affine_mat = (numpy.matrix(trans_mat) * numpy.matrix(rot_mat))[0:2, :]

    # Apply the transform
    result = cv2.warpAffine(
        image,
        affine_mat,
        (new_w, new_h),
        flags=cv2.INTER_LINEAR
    )

    return result

def rotate_dataset(input, rot_amount=45):

    out_x = numpy.zeros(input.shape, dtype='float32')
    out_y = numpy.zeros(input.shape[0], dtype='float32')

    for i,image in enumerate(input):

        # get a random angle
        rotation_angle = numpy.random.randint(low=-rot_amount, high=rot_amount)

        # rotate the image
        rotated_image = rotate(image, rotation_angle)

        # add dimension to account for the channels if the image is greyscale
        if rotated_image.ndim == 2:
            rotated_image = numpy.expand_dims(rotated_image, axis=2)

        rotated_image = cv2.resize(rotated_image, (image.shape[1], image.shape[0]))
        
        # store the image and label in their corresponding batches
        out_x[i] = rotated_image
        out_y[i] = rotation_angle       
    
    return out_x, out_y

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train_rot, y_train_rot = rotate_dataset(x_train, 45)
x_train_rot = x_train_rot.reshape(x_train_rot.shape[0], 28, 28, 1)
x_test_rot, y_test_rot = rotate_dataset(x_test, 45)
x_test_rot = x_test_rot.reshape(x_test_rot.shape[0], 28, 28, 1)

# %% [markdown]
# ## The Network
#
# We're going to keep it simple, and again borrow heavily from the previous example. The only difference is that we now have an extra dense layer, and an extra output.
#
# We set this up such that after the flatten, we have two dense layers, each of the same size, and then our two outputs, one for size 1 (for the rotation angle) and one of size 10 (for the class). Note that when it comes to building the model, the only difference is that we now have two outputs rather than one.

# %%
inputs = keras.Input(shape=(28, 28, 1, ), name='img')
x = layers.Conv2D(filters=8, kernel_size=(3,3), activation='relu')(inputs)
x = layers.MaxPool2D(pool_size=(2, 2))(x)
x = layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu')(x)
x = layers.MaxPool2D(pool_size=(2, 2))(x)
x = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu')(x)
x = layers.Flatten()(x)
x1 = layers.Dense(64, activation='relu')(x)
angle = layers.Dense(1, name='angle_out')(x1)
x2 = layers.Dense(64, activation='relu')(x)
label = layers.Dense(10, name='class_out')(x2)

model_cnn = keras.Model(inputs=inputs, outputs=[angle, label], name='mnist_cnn_multitask_model')
model_cnn.summary()
# Out:
# I0000 00:00:1768893107.449977 2916845 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 777 MB memory:  -> device: 0, name: NVIDIA A16-4Q, pci bus id: 0000:02:00.0, compute capability: 8.6
# Model: "mnist_cnn_multitask_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ img (InputLayer)    │ (None, 28, 28, 1) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 26, 26, 8) │         80 │ img[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 13, 13, 8) │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 11, 11,    │      1,168 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 5, 5, 16)  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 3, 3, 32)  │      4,640 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 288)       │          0 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     18,496 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │     18,496 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ angle_out (Dense)   │ (None, 1)         │         65 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class_out (Dense)   │ (None, 10)        │        650 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 43,595 (170.29 KB)
#  Trainable params: 43,595 (170.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Once we start using more complex topologies, the default text based graph that comes from summary() can be a bit hard to go through. Luckily we've been drawing pictures of networks thoughout our previous examples, and we'll lean more on these with the more complex networks.

# %%
plot_model(model_cnn, show_shapes=True, dpi=60)

# %% [markdown]
# The last step is our losses. This is again really simple, all we do is provide a list of them. If we have named our outputs, we could also do this via a dictionary.
#
# Afer that, we can train our models as per usual.

# %%
model_cnn.compile(loss=['mean_squared_error', keras.losses.SparseCategoricalCrossentropy(from_logits=True)],
                  optimizer=keras.optimizers.RMSprop(), 
                  # keras won't give me details for both losses by default, so I'm adding metrics for
                  # each loss to get the individual loss values
                  metrics=['mean_squared_error', keras.losses.SparseCategoricalCrossentropy(from_logits=True)], 
                  jit_compile=False)

# %%
history = model_cnn.fit(x_train_rot, [y_train_rot, y_train],
                    batch_size=64,
                    epochs=20,
                    validation_split=0.2)
# Out:
# Epoch 1/20
# I0000 00:00:1768893108.892013 2916885 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - angle_out_loss: 186.4551 - angle_out_mean_squared_error: 186.4551 - class_out_loss: 1.0092 - class_out_sparse_categorical_crossentropy: 1.0092 - loss: 187.4643 - val_angle_out_loss: 111.5475 - val_angle_out_mean_squared_error: 111.5492 - val_class_out_loss: 0.3867 - val_class_out_sparse_categorical_crossentropy: 0.3867 - val_loss: 111.9366
# Epoch 2/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 112.9792 - angle_out_mean_squared_error: 112.9792 - class_out_loss: 0.3036 - class_out_sparse_categorical_crossentropy: 0.3036 - loss: 113.2829 - val_angle_out_loss: 90.0220 - val_angle_out_mean_squared_error: 90.0572 - val_class_out_loss: 0.2279 - val_class_out_sparse_categorical_crossentropy: 0.2279 - val_loss: 90.2855
# Epoch 3/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 95.0116 - angle_out_mean_squared_error: 95.0116 - class_out_loss: 0.2223 - class_out_sparse_categorical_crossentropy: 0.2223 - loss: 95.2338 - val_angle_out_loss: 81.9463 - val_angle_out_mean_squared_error: 81.9578 - val_class_out_loss: 0.2071 - val_class_out_sparse_categorical_crossentropy: 0.2071 - val_loss: 82.1653
# Epoch 4/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 84.8901 - angle_out_mean_squared_error: 84.8901 - class_out_loss: 0.1855 - class_out_sparse_categorical_crossentropy: 0.1855 - loss: 85.0757 - val_angle_out_loss: 93.0554 - val_angle_out_mean_squared_error: 93.0844 - val_class_out_loss: 0.1949 - val_class_out_sparse_categorical_crossentropy: 0.1949 - val_loss: 93.2798
# Epoch 5/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 78.2273 - angle_out_mean_squared_error: 78.2273 - class_out_loss: 0.1594 - class_out_sparse_categorical_crossentropy: 0.1594 - loss: 78.3868 - val_angle_out_loss: 72.9120 - val_angle_out_mean_squared_error: 72.9307 - val_class_out_loss: 0.1831 - val_class_out_sparse_categorical_crossentropy: 0.1831 - val_loss: 73.1143
# Epoch 6/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 72.1071 - angle_out_mean_squared_error: 72.1071 - class_out_loss: 0.1473 - class_out_sparse_categorical_crossentropy: 0.1473 - loss: 72.2544 - val_angle_out_loss: 78.3428 - val_angle_out_mean_squared_error: 78.3465 - val_class_out_loss: 0.1758 - val_class_out_sparse_categorical_crossentropy: 0.1758 - val_loss: 78.5228
# Epoch 7/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 68.5729 - angle_out_mean_squared_error: 68.5729 - class_out_loss: 0.1389 - class_out_sparse_categorical_crossentropy: 0.1389 - loss: 68.7117 - val_angle_out_loss: 79.6303 - val_angle_out_mean_squared_error: 79.7160 - val_class_out_loss: 0.1865 - val_class_out_sparse_categorical_crossentropy: 0.1865 - val_loss: 79.9030
# Epoch 8/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 64.7299 - angle_out_mean_squared_error: 64.7299 - class_out_loss: 0.1269 - class_out_sparse_categorical_crossentropy: 0.1269 - loss: 64.8567 - val_angle_out_loss: 69.2223 - val_angle_out_mean_squared_error: 69.2402 - val_class_out_loss: 0.1764 - val_class_out_sparse_categorical_crossentropy: 0.1764 - val_loss: 69.4171
# Epoch 9/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 61.8296 - angle_out_mean_squared_error: 61.8296 - class_out_loss: 0.1206 - class_out_sparse_categorical_crossentropy: 0.1206 - loss: 61.9501 - val_angle_out_loss: 64.9797 - val_angle_out_mean_squared_error: 64.9958 - val_class_out_loss: 0.1886 - val_class_out_sparse_categorical_crossentropy: 0.1886 - val_loss: 65.1848
# Epoch 10/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 59.2483 - angle_out_mean_squared_error: 59.2483 - class_out_loss: 0.1126 - class_out_sparse_categorical_crossentropy: 0.1126 - loss: 59.3609 - val_angle_out_loss: 77.3595 - val_angle_out_mean_squared_error: 77.3780 - val_class_out_loss: 0.1846 - val_class_out_sparse_categorical_crossentropy: 0.1846 - val_loss: 77.5629
# Epoch 11/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 56.9735 - angle_out_mean_squared_error: 56.9735 - class_out_loss: 0.1060 - class_out_sparse_categorical_crossentropy: 0.1060 - loss: 57.0794 - val_angle_out_loss: 70.8170 - val_angle_out_mean_squared_error: 70.8482 - val_class_out_loss: 0.1849 - val_class_out_sparse_categorical_crossentropy: 0.1849 - val_loss: 71.0336
# Epoch 12/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 54.5089 - angle_out_mean_squared_error: 54.5089 - class_out_loss: 0.1015 - class_out_sparse_categorical_crossentropy: 0.1015 - loss: 54.6103 - val_angle_out_loss: 66.1768 - val_angle_out_mean_squared_error: 66.1919 - val_class_out_loss: 0.2112 - val_class_out_sparse_categorical_crossentropy: 0.2112 - val_loss: 66.4036
# Epoch 13/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 53.0192 - angle_out_mean_squared_error: 53.0192 - class_out_loss: 0.0972 - class_out_sparse_categorical_crossentropy: 0.0972 - loss: 53.1164 - val_angle_out_loss: 67.3843 - val_angle_out_mean_squared_error: 67.4185 - val_class_out_loss: 0.2285 - val_class_out_sparse_categorical_crossentropy: 0.2285 - val_loss: 67.6475
# Epoch 14/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 50.7749 - angle_out_mean_squared_error: 50.7749 - class_out_loss: 0.0941 - class_out_sparse_categorical_crossentropy: 0.0941 - loss: 50.8689 - val_angle_out_loss: 60.2170 - val_angle_out_mean_squared_error: 60.2523 - val_class_out_loss: 0.2034 - val_class_out_sparse_categorical_crossentropy: 0.2034 - val_loss: 60.4561
# Epoch 15/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 49.4929 - angle_out_mean_squared_error: 49.4929 - class_out_loss: 0.0888 - class_out_sparse_categorical_crossentropy: 0.0888 - loss: 49.5817 - val_angle_out_loss: 66.4983 - val_angle_out_mean_squared_error: 66.5734 - val_class_out_loss: 0.2183 - val_class_out_sparse_categorical_crossentropy: 0.2183 - val_loss: 66.7923
# Epoch 16/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 48.7313 - angle_out_mean_squared_error: 48.7313 - class_out_loss: 0.0918 - class_out_sparse_categorical_crossentropy: 0.0918 - loss: 48.8231 - val_angle_out_loss: 62.2348 - val_angle_out_mean_squared_error: 62.3172 - val_class_out_loss: 0.2089 - val_class_out_sparse_categorical_crossentropy: 0.2089 - val_loss: 62.5267
# Epoch 17/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 47.1679 - angle_out_mean_squared_error: 47.1679 - class_out_loss: 0.0861 - class_out_sparse_categorical_crossentropy: 0.0861 - loss: 47.2541 - val_angle_out_loss: 67.6871 - val_angle_out_mean_squared_error: 67.7617 - val_class_out_loss: 0.2259 - val_class_out_sparse_categorical_crossentropy: 0.2259 - val_loss: 67.9882
# Epoch 18/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 45.7826 - angle_out_mean_squared_error: 45.7826 - class_out_loss: 0.0851 - class_out_sparse_categorical_crossentropy: 0.0851 - loss: 45.8677 - val_angle_out_loss: 60.1822 - val_angle_out_mean_squared_error: 60.2139 - val_class_out_loss: 0.2216 - val_class_out_sparse_categorical_crossentropy: 0.2216 - val_loss: 60.4361
# Epoch 19/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 44.9172 - angle_out_mean_squared_error: 44.9172 - class_out_loss: 0.0787 - class_out_sparse_categorical_crossentropy: 0.0787 - loss: 44.9959 - val_angle_out_loss: 61.7456 - val_angle_out_mean_squared_error: 61.7919 - val_class_out_loss: 0.2293 - val_class_out_sparse_categorical_crossentropy: 0.2293 - val_loss: 62.0218
# Epoch 20/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 43.6059 - angle_out_mean_squared_error: 43.6059 - class_out_loss: 0.0787 - class_out_sparse_categorical_crossentropy: 0.0787 - loss: 43.6847 - val_angle_out_loss: 64.2339 - val_angle_out_mean_squared_error: 64.3196 - val_class_out_loss: 0.2477 - val_class_out_sparse_categorical_crossentropy: 0.2477 - val_loss: 64.5679

# %%
def eval_models(model, x_test, y_test_rot, y_test, history):

    predictions_rot, predictions_label = model.predict(x_test_rot)

    indexes = keras.ops.argmax(predictions_label, axis=1)
    fig = plt.figure(figsize=[10, 10])
    ax = fig.add_subplot(1, 1, 1)
    cm = confusion_matrix(y_test, indexes)
    c = ConfusionMatrixDisplay(cm, display_labels=range(10))
    c.plot(ax = ax)

    fig = plt.figure(figsize=[15, 10])
    ax = fig.add_subplot(1, 1, 1)
    data = []
    labels = []
    for i in range(10):
        sample_idx = numpy.array(y_test == i)
        errors = numpy.subtract(predictions_rot[sample_idx, 0], y_test_rot[sample_idx])
        data.append(errors)
        labels.append(str(i))

    ax.boxplot(data, labels=labels);

    fig = plt.figure(figsize=[15, 8])
    ax = fig.add_subplot(2, 1, 1)
    ax.plot(history.history['loss'], label = 'Overall Loss')
    ax.plot(history.history['angle_out_mean_squared_error'], label = 'Angle Loss')
    ax.plot(history.history['class_out_sparse_categorical_crossentropy'], label = 'Classification Loss')
    ax.legend()
    ax.set_title('Training Loss')

    ax = fig.add_subplot(2, 1, 2)
    ax.plot(history.history['val_loss'], label = 'Overall Loss')
    ax.plot(history.history['val_angle_out_mean_squared_error'], label = 'Angle Loss')
    ax.plot(history.history['val_class_out_sparse_categorical_crossentropy'], label = 'Classification Loss')
    ax.legend()
    ax.set_title('Validation Loss')

eval_models(model_cnn, x_test, y_test_rot, y_test, history)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /tmp/ipykernel_2916845/2490661063.py:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=labels);

# %% [markdown]
# From the above, we can see that we've learnt both tasks fairly well. We can also see though that our losses are in very different scales, our angle loss is roughly 100 times our classification loss.
#
# ## Loss Weights
#
# If we want to change our loss weights, which can help our network consider all tasks equally, again it's trivially simple. We just provide a list (or dictionary) of loss weights to the compile command when we build the model.

# %%
inputs = keras.Input(shape=(28, 28, 1, ), name='img')
x = layers.Conv2D(filters=8, kernel_size=(3,3), activation='relu')(inputs)
x = layers.MaxPool2D(pool_size=(2, 2))(x)
x = layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu')(x)
x = layers.MaxPool2D(pool_size=(2, 2))(x)
x = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu')(x)
x = layers.Flatten()(x)
x1 = layers.Dense(64, activation='relu')(x)
angle = layers.Dense(1, name='angle_out')(x1)
x2 = layers.Dense(64, activation='relu')(x)
label = layers.Dense(10, name='class_out')(x2)

model_cnn = keras.Model(inputs=inputs, outputs=[angle, label], name='mnist_cnn_multitask_model2')
model_cnn.compile(loss=['mean_squared_error', keras.losses.SparseCategoricalCrossentropy(from_logits=True)],
                  loss_weights=[1, 100],
                  optimizer=keras.optimizers.RMSprop(),
                  metrics=['mean_squared_error', keras.losses.SparseCategoricalCrossentropy(from_logits=True)], 
                  jit_compile=False)

history = model_cnn.fit(x_train_rot, [y_train_rot, y_train],
                    batch_size=64,
                    epochs=20,
                    validation_split=0.2)
# Out:
# Epoch 1/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - angle_out_loss: 200.5675 - angle_out_mean_squared_error: 200.5675 - class_out_loss: 0.7460 - class_out_sparse_categorical_crossentropy: 0.7460 - loss: 275.1710 - val_angle_out_loss: 114.0479 - val_angle_out_mean_squared_error: 114.0410 - val_class_out_loss: 0.2556 - val_class_out_sparse_categorical_crossentropy: 0.2556 - val_loss: 139.6052
# Epoch 2/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 107.9384 - angle_out_mean_squared_error: 107.9384 - class_out_loss: 0.2004 - class_out_sparse_categorical_crossentropy: 0.2004 - loss: 127.9767 - val_angle_out_loss: 85.3416 - val_angle_out_mean_squared_error: 85.2897 - val_class_out_loss: 0.1627 - val_class_out_sparse_categorical_crossentropy: 0.1627 - val_loss: 101.5921
# Epoch 3/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 90.0562 - angle_out_mean_squared_error: 90.0562 - class_out_loss: 0.1474 - class_out_sparse_categorical_crossentropy: 0.1474 - loss: 104.7955 - val_angle_out_loss: 85.2227 - val_angle_out_mean_squared_error: 85.2807 - val_class_out_loss: 0.1468 - val_class_out_sparse_categorical_crossentropy: 0.1468 - val_loss: 99.9811
# Epoch 4/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 81.0034 - angle_out_mean_squared_error: 81.0034 - class_out_loss: 0.1194 - class_out_sparse_categorical_crossentropy: 0.1194 - loss: 92.9385 - val_angle_out_loss: 71.8488 - val_angle_out_mean_squared_error: 71.8620 - val_class_out_loss: 0.1554 - val_class_out_sparse_categorical_crossentropy: 0.1554 - val_loss: 87.4431
# Epoch 5/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 75.0113 - angle_out_mean_squared_error: 75.0113 - class_out_loss: 0.1013 - class_out_sparse_categorical_crossentropy: 0.1013 - loss: 85.1378 - val_angle_out_loss: 74.7459 - val_angle_out_mean_squared_error: 74.7847 - val_class_out_loss: 0.1422 - val_class_out_sparse_categorical_crossentropy: 0.1422 - val_loss: 89.0305
# Epoch 6/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 70.5920 - angle_out_mean_squared_error: 70.5920 - class_out_loss: 0.0913 - class_out_sparse_categorical_crossentropy: 0.0913 - loss: 79.7220 - val_angle_out_loss: 69.2249 - val_angle_out_mean_squared_error: 69.2401 - val_class_out_loss: 0.1419 - val_class_out_sparse_categorical_crossentropy: 0.1419 - val_loss: 83.4293
# Epoch 7/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 66.2812 - angle_out_mean_squared_error: 66.2812 - class_out_loss: 0.0812 - class_out_sparse_categorical_crossentropy: 0.0812 - loss: 74.4036 - val_angle_out_loss: 75.6407 - val_angle_out_mean_squared_error: 75.6104 - val_class_out_loss: 0.1398 - val_class_out_sparse_categorical_crossentropy: 0.1398 - val_loss: 89.5982
# Epoch 8/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 63.0824 - angle_out_mean_squared_error: 63.0824 - class_out_loss: 0.0763 - class_out_sparse_categorical_crossentropy: 0.0763 - loss: 70.7100 - val_angle_out_loss: 80.3052 - val_angle_out_mean_squared_error: 80.4155 - val_class_out_loss: 0.1507 - val_class_out_sparse_categorical_crossentropy: 0.1507 - val_loss: 95.5186
# Epoch 9/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 60.9882 - angle_out_mean_squared_error: 60.9882 - class_out_loss: 0.0670 - class_out_sparse_categorical_crossentropy: 0.0670 - loss: 67.6882 - val_angle_out_loss: 65.6805 - val_angle_out_mean_squared_error: 65.7526 - val_class_out_loss: 0.1456 - val_class_out_sparse_categorical_crossentropy: 0.1456 - val_loss: 80.3531
# Epoch 10/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 57.9572 - angle_out_mean_squared_error: 57.9572 - class_out_loss: 0.0632 - class_out_sparse_categorical_crossentropy: 0.0632 - loss: 64.2810 - val_angle_out_loss: 63.2477 - val_angle_out_mean_squared_error: 63.3112 - val_class_out_loss: 0.1574 - val_class_out_sparse_categorical_crossentropy: 0.1574 - val_loss: 79.0876
# Epoch 11/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 56.5081 - angle_out_mean_squared_error: 56.5081 - class_out_loss: 0.0573 - class_out_sparse_categorical_crossentropy: 0.0573 - loss: 62.2424 - val_angle_out_loss: 68.2361 - val_angle_out_mean_squared_error: 68.2575 - val_class_out_loss: 0.1953 - val_class_out_sparse_categorical_crossentropy: 0.1953 - val_loss: 87.8339
# Epoch 12/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 54.6876 - angle_out_mean_squared_error: 54.6876 - class_out_loss: 0.0544 - class_out_sparse_categorical_crossentropy: 0.0544 - loss: 60.1299 - val_angle_out_loss: 68.9078 - val_angle_out_mean_squared_error: 68.9634 - val_class_out_loss: 0.1633 - val_class_out_sparse_categorical_crossentropy: 0.1633 - val_loss: 85.3351
# Epoch 13/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 52.5866 - angle_out_mean_squared_error: 52.5866 - class_out_loss: 0.0512 - class_out_sparse_categorical_crossentropy: 0.0512 - loss: 57.7102 - val_angle_out_loss: 60.9432 - val_angle_out_mean_squared_error: 61.0163 - val_class_out_loss: 0.1602 - val_class_out_sparse_categorical_crossentropy: 0.1602 - val_loss: 77.0753
# Epoch 14/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 50.8415 - angle_out_mean_squared_error: 50.8415 - class_out_loss: 0.0496 - class_out_sparse_categorical_crossentropy: 0.0496 - loss: 55.8022 - val_angle_out_loss: 64.3001 - val_angle_out_mean_squared_error: 64.3764 - val_class_out_loss: 0.1778 - val_class_out_sparse_categorical_crossentropy: 0.1778 - val_loss: 82.2029
# Epoch 15/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 49.7314 - angle_out_mean_squared_error: 49.7314 - class_out_loss: 0.0466 - class_out_sparse_categorical_crossentropy: 0.0466 - loss: 54.3920 - val_angle_out_loss: 63.5455 - val_angle_out_mean_squared_error: 63.6188 - val_class_out_loss: 0.1616 - val_class_out_sparse_categorical_crossentropy: 0.1616 - val_loss: 79.8116
# Epoch 16/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 48.5188 - angle_out_mean_squared_error: 48.5188 - class_out_loss: 0.0431 - class_out_sparse_categorical_crossentropy: 0.0431 - loss: 52.8255 - val_angle_out_loss: 66.1956 - val_angle_out_mean_squared_error: 66.2810 - val_class_out_loss: 0.1866 - val_class_out_sparse_categorical_crossentropy: 0.1866 - val_loss: 84.9840
# Epoch 17/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 47.3143 - angle_out_mean_squared_error: 47.3143 - class_out_loss: 0.0421 - class_out_sparse_categorical_crossentropy: 0.0421 - loss: 51.5210 - val_angle_out_loss: 61.9021 - val_angle_out_mean_squared_error: 61.9586 - val_class_out_loss: 0.1895 - val_class_out_sparse_categorical_crossentropy: 0.1895 - val_loss: 80.9594
# Epoch 18/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 46.4147 - angle_out_mean_squared_error: 46.4147 - class_out_loss: 0.0392 - class_out_sparse_categorical_crossentropy: 0.0392 - loss: 50.3319 - val_angle_out_loss: 60.3834 - val_angle_out_mean_squared_error: 60.4319 - val_class_out_loss: 0.2134 - val_class_out_sparse_categorical_crossentropy: 0.2134 - val_loss: 81.8274
# Epoch 19/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 45.3988 - angle_out_mean_squared_error: 45.3988 - class_out_loss: 0.0358 - class_out_sparse_categorical_crossentropy: 0.0358 - loss: 48.9739 - val_angle_out_loss: 63.7456 - val_angle_out_mean_squared_error: 63.8188 - val_class_out_loss: 0.1796 - val_class_out_sparse_categorical_crossentropy: 0.1796 - val_loss: 81.8224
# Epoch 20/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - angle_out_loss: 44.1516 - angle_out_mean_squared_error: 44.1516 - class_out_loss: 0.0356 - class_out_sparse_categorical_crossentropy: 0.0356 - loss: 47.7107 - val_angle_out_loss: 60.5909 - val_angle_out_mean_squared_error: 60.6919 - val_class_out_loss: 0.2040 - val_class_out_sparse_categorical_crossentropy: 0.2040 - val_loss: 81.1453

# %%
eval_models(model_cnn, x_test, y_test_rot, y_test, history)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# /tmp/ipykernel_2916845/2490661063.py:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=labels);

# %% [markdown]
# Note that the "Classification Loss" line hasn't moved, but there's now more of a gap between the angle and overall lines. The classification loss shows the unweighted loss (i.e. without the $\times 100$), while the overall loss shows the weighted sum. The gap between the overall and angle loss lines makes it clear that the loss weights are being applied.
#
# That said, performance doesn't change much in this case. As much as anything that's a result of the simple task rather than the loss weights not doing anything.
#
# ## Final Thoughts
#
# So what have we learnt today?
#
# Multi-task learning is actually quite simple, and can work quite well. The trick is to pick tasks that have something in common. For a dataset like this that's fairly easy, but as the same time there's only so much you can do with digits.
#
# One challenge that we have with other datasets and multiple loss is having labels for each task. This is where things such as auto-encoders, which are self-supervised (i.e. the output is the same as the input) can come in handy.
#
# We've also learnt that setting it all up is actually really easy. You just add another output, specify it's loss, and you're off. This process extends to adding multiple inputs too.
